# %%
from data_extraction.fetch_data import DailyStockDataLoader
import matplotlib.pyplot as plt

# %%
# Example usage
loader = DailyStockDataLoader()
nvda_data = loader.load_daily_row_stock_data('NVDA', last_n_years=5)

nvda_data['adjusted_close'].plot()
plt.show()

# %%
# import pandas_market_calendars as mcal
