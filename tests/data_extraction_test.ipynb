# %%
from data_extraction.fetch_data import fetch_daily_row_stock_data, update_daily_row_stock_data
import matplotlib.pyplot as plt

# %%
data = fetch_daily_row_stock_data('NVDA', 5)

data['adjusted_close'].plot()
plt.show()

# %%
# import pandas_market_calendars as mcal

# %%
# Example usage:
update_daily_row_stock_data('NVDA')
